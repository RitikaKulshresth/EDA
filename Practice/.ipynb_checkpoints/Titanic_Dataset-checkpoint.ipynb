# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic_df = pd.read_csv('titanic_train.csv')

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_df.shape
# Out:
# (891, 12)

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Check the data types of variables
print(titanic_df.dtypes)
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic_df.isnull().sum()/len(titanic_df)*100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
#missing values
#Encoding
#outlier
#Standardisation
#imbalance dataset

# %%
# identify datatypes of the 11 columns, add the stats to the datadict
datadict = pd.DataFrame(titanic_df.dtypes)
datadict
# Out:
#                    0
# PassengerId    int64
# Survived       int64
# Pclass         int64
# Name          object
# Sex           object
# Age          float64
# SibSp          int64
# Parch          int64
# Ticket        object
# Fare         float64
# Cabin         object
# Embarked      object

# %%
# identify datatypes of the 11 columns, add the stats to the datadict
datadict['Missing_Val'] = titanic_df.isnull().sum()
datadict
# Out:
#                    0  Missing_Val
# PassengerId    int64            0
# Survived       int64            0
# Pclass         int64            0
# Name          object            0
# Sex           object            0
# Age          float64          177
# SibSp          int64            0
# Parch          int64            0
# Ticket        object            0
# Fare         float64            0
# Cabin         object          687
# Embarked      object            2

# %%
datadict['Unique_Val'] = titanic_df.nunique()
datadict
# Out:
#                    0  Missing_Val  Unique_Val
# PassengerId    int64            0         891
# Survived       int64            0           2
# Pclass         int64            0           3
# Name          object            0         891
# Sex           object            0           2
# Age          float64          177          88
# SibSp          int64            0           7
# Parch          int64            0           7
# Ticket        object            0         681
# Fare         float64            0         248
# Cabin         object          687         147
# Embarked      object            2           3

# %%
datadict['Count'] = titanic_df.count()
datadict
# Out:
#                    0  Missing_Val  Unique_Val  Count
# PassengerId    int64            0         891    891
# Survived       int64            0           2    891
# Pclass         int64            0           3    891
# Name          object            0         891    891
# Sex           object            0           2    891
# Age          float64          177          88    714
# SibSp          int64            0           7    891
# Parch          int64            0           7    891
# Ticket        object            0         681    891
# Fare         float64            0         248    891
# Cabin         object          687         147    204
# Embarked      object            2           3    889

# %%
datadict['Missing_Percentage'] = titanic_df.isnull().sum()/len(titanic_df)*100
datadict
# Out:
#                    0  Missing_Val  Unique_Val  Count  Missing_Percentage
# PassengerId    int64            0         891    891            0.000000
# Survived       int64            0           2    891            0.000000
# Pclass         int64            0           3    891            0.000000
# Name          object            0         891    891            0.000000
# Sex           object            0           2    891            0.000000
# Age          float64          177          88    714           19.865320
# SibSp          int64            0           7    891            0.000000
# Parch          int64            0           7    891            0.000000
# Ticket        object            0         681    891            0.000000
# Fare         float64            0         248    891            0.000000
# Cabin         object          687         147    204           77.104377
# Embarked      object            2           3    889            0.224467

# %%
# datadict = datadict.rename(columns={0:'DataType'})
datadict = datadict.rename(columns={0:'Datatype'})

# %%
datadict
# Out:
#             Datatype  Missing_Val  Unique_Val  Count  Missing_Percentage
# PassengerId    int64            0         891    891            0.000000
# Survived       int64            0           2    891            0.000000
# Pclass         int64            0           3    891            0.000000
# Name          object            0         891    891            0.000000
# Sex           object            0           2    891            0.000000
# Age          float64          177          88    714           19.865320
# SibSp          int64            0           7    891            0.000000
# Parch          int64            0           7    891            0.000000
# Ticket        object            0         681    891            0.000000
# Fare         float64            0         248    891            0.000000
# Cabin         object          687         147    204           77.104377
# Embarked      object            2           3    889            0.224467

# %%
titanic_df.describe(include='object')
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
titanic_df.describe(include=['number'])
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic_df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
titanic_df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
titanic_df[['Survived','Pclass','SibSp','Parch']].apply(pd.Series.value_counts)
# Out:
#    Survived  Pclass  SibSp  Parch
# 0     549.0     NaN  608.0  678.0
# 1     342.0   216.0  209.0  118.0
# 2       NaN   184.0   28.0   80.0
# 3       NaN   491.0   16.0    5.0
# 4       NaN     NaN   18.0    4.0
# 5       NaN     NaN    5.0    5.0
# 6       NaN     NaN    NaN    1.0
# 8       NaN     NaN    7.0    NaN

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_df['Name_len']=titanic_df.Name.str.len()

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Name_len
# 0      0         A/5 21171   7.2500   NaN        S        23
# 1      0          PC 17599  71.2833   C85        C        51
# 2      0  STON/O2. 3101282   7.9250   NaN        S        22
# 3      0            113803  53.1000  C123        S        44
# ...

# %%
final_df = titanic_df.copy()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Check missing values
print(final_df.isnull().sum())

# Visualize missing values
sns.heatmap(final_df.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Name_len         0
# dtype: int64

# %%
# Common missing values:
# Age: Fill using the median or mean.
# Cabin: Consider dropping or creating a new feature indicating cabin presence.
# Embarked: Fill missing values with the most common port (mode).

# %%
final_df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %% [markdown]
# # Univariate Analysis
#
# Categorical Variables: Use countplot to see the distribution.
#
# Numerical Variables: Use histograms and box plots to observe distributions and outliers.

# %%
final_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Name_len
# 0      0         A/5 21171   7.2500   NaN        S        23
# 1      0          PC 17599  71.2833   C85        C        51
# 2      0  STON/O2. 3101282   7.9250   NaN        S        22
# 3      0            113803  53.1000  C123        S        44
# ...

# %%
# Categorical - Pclass,Name,Sex,Ticket,Embarked

sns.countplot(x='Pclass',data=final_df)
plt.title('Passenger Class Distribution')
plt.show()

sns.countplot(x='Sex',data=final_df)
plt.title('Sex')
plt.show()

sns.countplot(x='Embarked',data=final_df)
plt.title('Embarked')
plt.show()

# sns.countplot(x='Survived',data=final_df)
# plt.title('Survived')
# plt.show()

# %%
# Numerical: Age, Fare
# Age	SibSp	Parch	Fare
final_df['Age'].hist(bins=30, edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

final_df['SibSp'].hist(bins=30,edgecolor='black')
plt.title('Siblings Count')
plt.xlabel('SibSp')
plt.ylabel('Frequency')
plt.show()

final_df['Parch'].hist(bins=30,edgecolor='black')
plt.title('Parents count')
plt.xlabel('Parch')
plt.ylabel('Frequency')
plt.show()

final_df['Fare'].hist(bins=30,edgecolor='black')
plt.title('Fare')
plt.xlabel('Fare')
plt.ylabel('Frequency')
plt.show()

# %%
datadict
# Out:
#             Datatype  Missing_Val  Unique_Val  Count  Missing_Percentage
# PassengerId    int64            0         891    891            0.000000
# Survived       int64            0           2    891            0.000000
# Pclass         int64            0           3    891            0.000000
# Name          object            0         891    891            0.000000
# Sex           object            0           2    891            0.000000
# Age          float64          177          88    714           19.865320
# SibSp          int64            0           7    891            0.000000
# Parch          int64            0           7    891            0.000000
# Ticket        object            0         681    891            0.000000
# Fare         float64            0         248    891            0.000000
# Cabin         object          687         147    204           77.104377
# Embarked      object            2           3    889            0.224467

# %%
sns.boxplot(x='Pclass', y='Age', data=final_df)
plt.title('Age Distribution by Passenger Class')
plt.show()

# %%
sns.boxplot(y = 'Age',data=final_df)
plt.title('Passenger_Age')
plt.show()

# %%
sns.boxplot(y='Fare', data=titanic_df)
plt.title('Fare Distribution')
plt.show()

# %%
sns.boxplot(y='SibSp', data=titanic_df)
plt.title('Number of Siblings/Spouses Aboard Distribution')
plt.show()

sns.boxplot(y='Parch', data=titanic_df)
plt.title('Number of Parents/Children Aboard Distribution')
plt.show()
